# %%
f = open("./CelebA_Anno/list_attr_celeba.txt")
newTxt = "glass.txt"
newf = open(newTxt, "a+")
newNoTxt = "noGlass.txt"
newNof = open(newNoTxt, "a+")

line = f.readline() 
line = f.readline() 
line = f.readline() 
while line:
    array = line.split()
    if (array[0] == "000154.jpg"): print(array[16])

    if (array[16] == "-1"): 
        new_context = array[0] + '\n'
        newNof.write(new_context)
    else: 
        new_context = array[0] + '\n'
        newf.write(new_context)
    line = f.readline()

lines = len(newf.readlines()) 
print ("There are %d lines in %s" % (lines, newTxt)) 
lines = len(newNof.readlines()) 
print ("There are %d lines in %s" % (lines, newNoTxt))

f.close()
newf.close()
newNof.close()
# Out:
# 1
# There are 0 lines in glass.txt
# There are 0 lines in noGlass.txt

# %%
f = open("/afs/inf.ed.ac.uk/user/s22/s2226904/Final_Project/pythonProject/CelebA_Anno/list_attr_celeba.txt")
newTxt = "Young.txt"
newf = open(newTxt, "a+")

line = f.readline() 
line = f.readline() 
line = f.readline() 
while line:
    array = line.split()
    
    if (array[40] == "1"): 
        new_context = array[0] + '\n'
        newf.write(new_context)
        
    line = f.readline()


f.close()
newf.close()

# %%
import os
import shutil

#nof = open("noGlass.txt")
hasf = open("5_o_Clock_Shadow.txt")

#noLine = nof.readline() 
hasLine = hasf.readline() 

list1 = os.listdir("./CelebA/Img/img_align_celeba")
hasGo = True
#noGo = True

x = 0
i = 0

while x < 65:
    imgName = os.path.basename(list1[i])
    if (os.path.splitext(imgName)[1] != ".jpg"): continue

    #noArray = noLine.split()
    #if (len(noArray) < 1): noGo = False
    hasArray = hasLine.split()
    if (len(hasArray) < 1): hasGo = False

    #if (noGo and (imgName == noArray[0])):
        #oldname= "./"+imgName
        #newname="./noGlass/"+imgName
        #shutil.move(oldname, newname)
        #noLine = nof.readline()
    if (hasGo and (imgName == hasArray[0])):
        oldname= "./"+imgName
        newname="./has/"+imgName
        shutil.move(oldname, newname)
        hasLine = hasf.readline()
        x += 1
    i +=1

    
hasf.close()

# %%
f = open("/afs/inf.ed.ac.uk/user/s22/s2226904/Final_Project/pythonProject/CelebA_Anno/list_attr_celeba.txt")

attr_num = [0]*40

line = f.readline() 
line1 = f.readline().split()
print(line1)
line = f.readline() 
while line:
    array = line.split()
    
    for i in range(1, 41):
        if (array[i] == "1"): 
            attr_num[i-1]+=1
    line = f.readline()
        
print(attr_num)
# Out:
# ['5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive', 'Bags_Under_Eyes', 'Bald', 'Bangs', 'Big_Lips', 'Big_Nose', 'Black_Hair', 'Blond_Hair', 'Blurry', 'Brown_Hair', 'Bushy_Eyebrows', 'Chubby', 'Double_Chin', 'Eyeglasses', 'Goatee', 'Gray_Hair', 'Heavy_Makeup', 'High_Cheekbones', 'Male', 'Mouth_Slightly_Open', 'Mustache', 'Narrow_Eyes', 'No_Beard', 'Oval_Face', 'Pale_Skin', 'Pointy_Nose', 'Receding_Hairline', 'Rosy_Cheeks', 'Sideburns', 'Smiling', 'Straight_Hair', 'Wavy_Hair', 'Wearing_Earrings', 'Wearing_Hat', 'Wearing_Lipstick', 'Wearing_Necklace', 'Wearing_Necktie', 'Young']
# [22516, 54090, 103833, 41446, 4547, 30709, 48785, 47516, 48472, 29983, 10312, 41572, 28803, 11663, 9459, 13193, 12716, 8499, 78390, 92189, 84434, 97942, 8417, 23329, 169158, 57567, 8701, 56210, 16163, 13315, 11449, 97669, 42222, 64744, 38276, 9818, 95715, 24913, 14732, 156734]

# %%
import numpy as np  
import matplotlib.mlab as mlab  
import matplotlib.pyplot as plt  

bar = plt.bar(line1, attr_num, 1, color='coral',edgecolor='grey')

for a,b in zip(line1, attr_num):
    plt.text(a,b,
             b,
             ha='center', 
             va='bottom',
            )

# %%
import numpy as np
j = np.log(5)
print(j)
# Out:
# 1.6094379124341003
